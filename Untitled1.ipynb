# %%
# !pip install flask-pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      |████████████████████████████████| 527 kB 580 kB/s
# ...

# %%
# %%writefile database.py
import pymongo
import pickle
from pymongo import MongoClient

client = MongoClient()
db = client['test']

class Database:
    def __init__(self):
        self.db = None
    
    def connect(self):
        self.db = db
    
    def disconnect(self):
        self.db = None
    
    def get_tournament(self, tournament_id):
        result = self.db['tournaments'].find_one({'tournament_id':tournament_id})
        
        return result
    
    def get_match(self, match_id):
        result = self.db['matches'].find_one({'match_id':match_id})
        
        return result
# Out:
# Writing database.py

# %%
import pickle

client = MongoClient()
db = client['test']
matches = db['matches']
tournaments = db['tournaments']

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client['test']

# %%
matches = db['matches']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-062bb4557129> in <module>
# ----> 1 db.get_collection()
#
# TypeError: get_collection() missing 1 required positional argument: 'name'

# %%
db = Database()

# %%
db.connect()

# %%
for i in db['matches'].find():
    print(i)
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0c1479382ecf> in <module>
# ----> 1 for i in db['matches'].find():
#       2     print(i)
#       3     break
#
# TypeError: 'Database' object is not subscriptable

# %%
tournaments = db['tournaments']

# %%
import pickle

# %%
with open('all_matches.pickle', 'rb') as f:
    all_matches = pickle.load(f)

# %%
with open('tournaments.pickle', 'rb') as f:
    all_tournaments = pickle.load(f)

# %%
len(all_matches.keys())
# Out:
# 386

# %%
for m in all_matches:
    print(m)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cacc1e088d5e> in <module>
# ----> 1 for m in all_matches:
#       2     print(m)
#       3     break
#
# NameError: name 'all_matches' is not defined

# %%
for match in matches.find():
    print(match)
    break
# Out:
# {'_id': ObjectId('619ec1b1bea0fd61b606eba3'), 'playerIdNameDictionary': {'410457': 'Mads Bidstrup', '101856': 'Christian Nørgaard', '329554': 'Mads Roerslev', '346304': 'Mads Bech Sørensen', '362215': 'Marcus Forss', '353377': 'Bryan Mbeumo', '296240': 'Yoane Wissa', '298689': 'Vitaly Janelt', '320575': 'Saman Ghoddos', '342499': 'Ethan Pinnock', '404109': 'Frank Onyeka', '321085': 'Kristoffer Ajer', '295964': 'Sergi Canós', '276366': 'David Raya', '121123': 'Pontus Jansson', '357083': 'Halil Dervisoglu', '283345': 'Charlie Goode', '134240': 'Ivan Toney', '229562': 'Rico Henry', '370992': 'Patrik Gunnarsson', '349102': 'Albert Sambi Lokonga', '380706': 'Gabriel Martinelli', '125209': 'Mohamed Elneny', '399501': 'Karl Hein', '92173': 'Bernd Leno', '69945': 'Cédric Soares', '379790': 'Nuno Tavares', '125211': 'Héctor Bellerín', '141032': 'Pablo Marí', '89401': 'Granit Xhaka', '124316': 'Calum Chambers', '255169': 'Ainsley Maitland-Niles', '288795': 'Rob Holding', '363686': 'Emile Smith
# ...

# %%
matches.count()
# Out:
# <ipython-input-21-fa1976ea3837>:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   matches.count()
# 0

# %%
result = matches.insert_many(all_matches.values())

# %%
all_tournaments.values()
# Out:
# dict_values([{'name': 'England-Premier-League-2021-2022', 'tournament_id': '19793', 'matches': [{'match_id': '1549539', 'date': '2021-08-13T00:00:00', 'homeId': 189, 'home': 'Brentford', 'score': '2 : 0', 'awayId': 13, 'away': 'Arsenal'}, {'match_id': '1549540', 'date': '2021-08-14T00:00:00', 'homeId': 184, 'home': 'Burnley', 'score': '1 : 2', 'awayId': 211, 'away': 'Brighton'}, {'match_id': '1549541', 'date': '2021-08-14T00:00:00', 'homeId': 15, 'home': 'Chelsea', 'score': '3 : 0', 'awayId': 162, 'away': 'Crystal Palace'}, {'match_id': '1549542', 'date': '2021-08-14T00:00:00', 'homeId': 31, 'home': 'Everton', 'score': '3 : 1', 'awayId': 18, 'away': 'Southampton'}, {'match_id': '1549543', 'date': '2021-08-14T00:00:00', 'homeId': 14, 'home': 'Leicester', 'score': '1 : 0', 'awayId': 161, 'away': 'Wolves'}, {'match_id': '1549544', 'date': '2021-08-14T00:00:00', 'homeId': 32, 'home': 'Man Utd', 'score': '5 : 1', 'awayId': 19, 'away': 'Leeds'}, {'match_id': '1549545', 'date': '2021-08-15T
# ...

# %%
result = tournaments.insert_many(all_tournaments.values())

# %%
tournaments.find()

# %%
all_matches[m].keys()
# Out:
# dict_keys(['playerIdNameDictionary', 'periodMinuteLimits', 'timeStamp', 'attendance', 'venueName', 'referee', 'weatherCode', 'elapsed', 'startTime', 'startDate', 'score', 'htScore', 'ftScore', 'etScore', 'pkScore', 'statusCode', 'periodCode', 'home', 'away', 'maxMinute', 'minuteExpanded', 'maxPeriod', 'expandedMinutes', 'expandedMaxMinute', 'periodEndMinutes', 'commonEvents', 'events', 'timeoutInSeconds', 'match_id', 'home_team_name', 'away_team_name'])

# %%
for tournament in tournaments.find():
    print(tournament['tournament_id'])
#     break
# Out:
# 19793
# 19895
# 19982

# %%
t = tournaments.find_one({'tournament_id':'19793'})

# %%
import json
from bson import json_util
from flask import jsonify

# %%
from flask import jsonify

# %%
from bson import json_util

# %%
json.loads(json_util.dumps(t))
# Out:
# {'_id': {'$oid': '619ec4c9bea0fd61b606ed25'},
#  'name': 'England-Premier-League-2021-2022',
#  'tournament_id': '19793',
#  'matches': [{'match_id': '1549539',
#    'date': '2021-08-13T00:00:00',
#    'homeId': 189,
#    'home': 'Brentford',
#    'score': '2 : 0',
#    'awayId': 13,
#    'away': 'Arsenal'},
#   {'match_id': '1549540',
#    'date': '2021-08-14T00:00:00',
#    'homeId': 184,
#    'home': 'Burnley',
#    'score': '1 : 2',
#    'awayId': 211,
#    'away': 'Brighton'},
#   {'match_id': '1549541',
#    'date': '2021-08-14T00:00:00',
#    'homeId': 15,
#    'home': 'Chelsea',
#    'score': '3 : 0',
#    'awayId': 162,
#    'away': 'Crystal Palace'},
#   {'match_id': '1549542',
#    'date': '2021-08-14T00:00:00',
#    'homeId': 31,
#    'home': 'Everton',
#    'score': '3 : 1',
#    'awayId': 18,
#    'away': 'Southampton'},
#   {'match_id': '1549543',
#    'date': '2021-08-14T00:00:00',
#    'homeId': 14,
#    'home': 'Leicester',
#    'score': '1 : 0',
# ...

# %%
db.get_tournament(19982)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2472c67ef5ab> in <module>
# ----> 1 db.get_tournament(19982)
#
# ~/Web/database.py in get_tournament(self, tournament_id)
#      17
#      18     def get_tournament(self, tournament_id):
# ---> 19         result = self.db['tournaments'].find_one({'tournament_id':tournament_id})
#      20
#      21         return result
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# %%writefile app_flask.py
import json
from bson import json_util
from database import Database
from flask import Flask, jsonify, Response


app = Flask(__name__)
db = Database()

db.connect()

@app.route('/')
def main_page():
    return 'Main page'

@app.route('/tournaments/<tournament_id>', methods=['GET'])
def tournament(tournament_id):
    result = db.get_tournament(tournament_id)
    if result is None:
        return Response('Page not found', status=404) 
    return json.loads(json_util.dumps(result))

@app.route('/matches/<match_id>', methods=['GET'])
def match(match_id):
    result = db.get_match(match_id)
    if result is None:
        return Response('Page not found', status=404) 
    return json.loads(json_util.dumps(result))

if __name__ == '__main__':
    app.run()
# Out:
# Overwriting app_flask.py

# %%
# !pip install fastapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      |████████████████████████████████| 51 kB 862 kB/s
# ...
#      |████████████████████████████████| 13.7 MB 2.6 MB/s
# ...
#      |████████████████████████████████| 61 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 78 kB 6.5 MB/s
# ...
#   Attempting uninstall: anyio
#     Found existing installation: anyio 2.2.0
#     Uninstalling anyio-2.2.0:
#       Successfully uninstalled anyio-2.2.0
# ...

# %%
# !pip install "uvicorn[standard]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      |████████████████████████████████| 54 kB 813 kB/s
# ...
#      |████████████████████████████████| 354 kB 2.4 MB/s
# ...
#   Attempting uninstall: httptools
#     Found existing installation: httptools 0.3.0
#     Uninstalling httptools-0.3.0:
#       Successfully uninstalled httptools-0.3.0
# ...

# %%
# %%writefile app_fast.py
import json
from bson import json_util
from database import Database

from fastapi import FastAPI


app = FastAPI()
db = Database()

db.connect()

@app.get('/')
def main_page():
    return 'Main page'

@app.get('/tournaments/{tournament_id}')
async def tournament(tournament_id):
    result = db.get_tournament(tournament_id)
#     if result is None:
#         return Response('Page not found', status=404) 
    return json.loads(json_util.dumps(result))

@app.route('/matches/{match_id}')
async def match(match_id):
    result = db.get_match(match_id)
#     if result is None:
#         return Response('Page not found', status=404) 
    return json.loads(json_util.dumps(result))

# if __name__ == '__main__':
#     app.run()
# Out:
# Overwriting app_fast.py

# %%
# !uvicorn app_fast:app --reload
# Out:
# INFO:     Will watch for changes in these directories: ['/home/ilya/Web']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [6597] using watchgod
# INFO:     Started server process [6599]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:39870 - "GET /tournaments/19982 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39872 - "GET /tournaments/19982 HTTP/1.0" 200 OK
# INFO:     127.0.0.1:39874 - "GET /tournaments/19982 HTTP/1.0" 200 OK
# INFO:     127.0.0.1:39876 - "GET /tournaments/19982 HTTP/1.0" 200 OK
# INFO:     127.0.0.1:39878 - "GET /tournaments/19982 HTTP/1.0" 200 OK
# INFO:     127.0.0.1:39880 - "GET /tournaments/19982 HTTP/1.0" 200 OK
# INFO:     127.0.0.1:39882 - "GET /tournaments/19982 HTTP/1.0" 200 OK
# INFO:     127.0.0.1:39884 - "GET /tournaments/19982 HTTP/1.0" 200 OK
# INFO:     127.0.0.1:39886 - "GET /tournaments/19982 HTTP/1.0" 200 OK
# ...

# %%
# %%writefile wsgi.py
from app_flask import app

if __name__ == '__main__':
    app.run()
# Out:
# Writing wsgi.py

# %%
# !pip install gunicorn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
# !gunicorn --workers 4 --bind 0.0.0.0:5000 wsgi:app
# Out:
# [2021-11-26 05:10:22 +0300] [17061] [INFO] Starting gunicorn 20.0.4
# [2021-11-26 05:10:22 +0300] [17061] [INFO] Listening at: http://0.0.0.0:5000 (17061)
# [2021-11-26 05:10:22 +0300] [17061] [INFO] Using worker: sync
# [2021-11-26 05:10:22 +0300] [17063] [INFO] Booting worker with pid: 17063
# [2021-11-26 05:10:22 +0300] [17064] [INFO] Booting worker with pid: 17064
# [2021-11-26 05:10:22 +0300] [17065] [INFO] Booting worker with pid: 17065
# [2021-11-26 05:10:22 +0300] [17076] [INFO] Booting worker with pid: 17076
# [2021-11-26 05:12:40 +0300] [17061] [CRITICAL] WORKER TIMEOUT (pid:17065)
# [2021-11-26 05:12:40 +0300] [17065] [INFO] Worker exiting (pid: 17065)
# [2021-11-26 05:12:40 +0300] [17273] [INFO] Booting worker with pid: 17273
# ^C
# [2021-11-26 05:19:11 +0300] [17061] [INFO] Handling signal: int
# [2021-11-26 05:19:11 +0300] [17076] [INFO] Worker exiting (pid: 17076)
# [2021-11-26 05:19:11 +0300] [17063] [INFO] Worker exiting (pid: 17063)
# ...

# %%
import nest_asyncio

# %%
nest_asyncio.apply()

# %%
# %%writefile app_sanic.py
from bson import json_util
from database import Database
from sanic import Sanic
from sanic.response import json, text
from sanic.exceptions import NotFound

app = Sanic("Sanic test")
db = Database()

db.connect()


@app.route('/')
async def main_page(request):
    return text('Main page')

@app.route('/tournaments/<tournament_id>')
async def tournament(request, tournament_id):
    result = db.get_tournament(tournament_id)
    if result is None:
        return NotFound('Page not found', status_code=404) 
    return json(json_util.dumps(result))

@app.route('/matches/<match_id>')
async def match(request, match_id):
    result = db.get_match(match_id)
    if result is None:
        return NotFound('Page not found', status_code=404)
    return json(json_util.dumps(result))

if __name__ == '__main__':
    app.run()
# Out:
# Overwriting app_sanic.py

# %%
# !sanic app_sanic.app
# Out:
# [2021-11-26 07:14:47 +0300] [6841] [INFO] Goin' Fast @ http://127.0.0.1:8000
# [2021-11-26 07:14:47 +0300] [6841] [INFO] Starting worker [6841]
# ^C
# [2021-11-26 07:16:08 +0300] [6841] [INFO] Stopping worker [6841]
# [2021-11-26 07:16:08 +0300] [6841] [INFO] Server Stopped

# %%
app.run()
# Out:
# [2021-11-25 23:34:14 +0300] [3932] [INFO] Goin' Fast @ http://127.0.0.1:8000
# [2021-11-25 23:34:14 +0300] [3932] [ERROR] Experienced exception while trying to serve
# Traceback (most recent call last):
#   File "/home/ilya/anaconda3/lib/python3.8/site-packages/sanic/app.py", line 1051, in run
#     serve_single(server_settings)
#   File "/home/ilya/anaconda3/lib/python3.8/site-packages/sanic/server/runners.py", line 199, in serve_single
#     serve(**server_settings)
#   File "/home/ilya/anaconda3/lib/python3.8/site-packages/sanic/server/runners.py", line 125, in serve
#     loop.run_until_complete(app._startup())
#   File "uvloop/loop.pyx", line 1495, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1488, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1377, in uvloop.loop.Loop.run_forever
#   File "uvloop/loop.pyx", line 515, in uvloop.loop.Loop._run
# RuntimeError: Cannot run the event loop while another loop is running
# ...
